# %% [markdown]
# # 作业1：问卷+环境配置

# %% [markdown]
# ## 0. 说明

# %% [markdown]
# ### 0.1 关于 Jupyter Notebook

# %% [markdown]
# Jupyter Notebook 是一种可编程的文档类型，类似于 R Markdown。Jupyter Notebook 文档以一个个单元格组成，每个单元格可以是 Markdown 或者 Python 代码：前者通常用来写文字说明，后者用来运行代码。比如你双击第一行的标题，就会看到标题的 Markdown 代码（以 `#` 符号开头），再按 `Ctrl+Enter`，就会显示 Markdown 渲染的结果。

# %% [markdown]
# 而对于代码单元格， `Ctrl+Enter` 会执行单元格内的代码，例如用鼠标点击下面的单元格然后按键后会出现形如 `Out[x]` 的输出结果。

# %%
import math

math.pi
# Out:
# 3.141592653589793

# %% [markdown]
# 我们的作业中既有需要说明的文字，又有需要编写的程序，前者用 Markdown 单元格，后者用代码单元格。单元格的类型可以在上方的下拉菜单中选择，也可以通过快捷键实现（通过菜单 Cell => Cell Type 查看）。

# %% [markdown]
# ### 0.2 关于 Markdown

# %% [markdown]
# Markdown 是常用的文档格式化语法，如果有不熟悉的，可以参考[这里](https://www.jianshu.com/p/335db5716248)的教程。需要说明的是 Jupyter Notebook 里可以插入数学公式，例如 $f(x)=\frac{1}{\sqrt{2\pi}}e^{-x^2/2}$。双击这个单元格来查看源代码。

# %% [markdown]
# ## 1. 练习

# %% [markdown]
# 1.1 请在下方插入一个 Markdown 单元格，输入一段文字，里面需包括斜体、粗体和列表格式。然后插入一张图片，图片地址使用相对路径，图片文件与 Notebook 一同上传。

# %% [markdown]
# - 苹果
# - 香蕉
# - 橙子
#
# 1. 第一步
# 2. 第二步
# 3. 第三步
#
# *老师好* ， **我叫张跃扬**
#
# ![图片](./photo.png.jpg)

# %% [markdown]
# 1.2 选取三个包含数学公式的定理，用 Markdown 格式在下方插入。

# %% [markdown]
# ## 2. 问卷

# %% [markdown]
# 思考并回答以下问题：

# %% [markdown]
# - 你现在对深度学习有多少了解？

# %% [markdown]
# 很少吧

# %% [markdown]
# - 你预期今后的工作/研究与深度学习关联大吗？

# %% [markdown]
# 可能会金融科技岗

# %% [markdown]
# - 你喜欢/**不**喜欢的上课方式是怎样的？你想从这门课中学到什么？

# %% [markdown]
# 希望教学和期末考核关联的大一些

# %% [markdown]
# - 你有哪些喜欢的获取知识的渠道（例如B站，知乎，技术博客，公众号等）？如果有请推荐一些，**具体到账号或网址**，不需要与本课程相关。回答仅作汇总使用，不会关联你的个人信息。

# %% [markdown]
# b站

# %% [markdown]
# - 你平时使用的 AI 工具有哪些？它们各自的使用场景是怎样的？

# %% [markdown]
# kimi

# %% [markdown]
# - 你觉得 AI 的发展对自己未来可能有哪些影响？是正向的还是负向的？

# %% [markdown]
# 负向的，岗位变少了

# %% [markdown]
# ## 2. 安装 PyTorch

# %% [markdown]
# 请参照课程文档《PyTorch安装》的提示配置好 PyTorch 环境。如果你的电脑具备 Nvidia 显卡，**优先尝试安装 GPU 版本**。用如下的代码验证 Conda 和 PyTorch 安装是否成功：

# %%
# !conda info
# Out:
#      active environment : pytorch
#     active env location : C:\Users\31805\miniconda3\envs\pytorch
#             shell level : 2
#        user config file : C:\Users\31805\.condarc
#  populated config files : C:\Users\31805\miniconda3\.condarc
#                           C:\Users\31805\miniconda3\condarc.d\anaconda-auth.yml
#                           C:\Users\31805\.condarc
#           conda version : 26.1.1
#     conda-build version : not installed
#          python version : 3.13.12.final.0
#                  solver : libmamba (default)
#        virtual packages : __archspec=1=skylake
#                           __conda=26.1.1=0
#                           __cuda=12.6=0
#                           __win=10.0.26200=0
#        base environment : C:\Users\31805\miniconda3  (writable)
#       conda av data dir : C:\Users\31805\miniconda3\etc\conda
#   conda av metadata url : None
#            channel URLs : https://mirrors.bfsu.edu.cn/anaconda/pkgs/main/win-64
#                           https://mirrors.bfsu.edu.cn/anaconda/pkgs/main/noarch
#                           https://mirrors.bfsu.edu.cn/anaconda/pkgs/free/win-64
#                           https://mirrors.bfsu.edu.cn/anaconda/pkgs/free/noarch
#                           https://mirrors.bfsu.edu.cn/anaconda/cloud/conda-forge/win-64
#                           https://mirrors.bfsu.edu.cn/anaconda/cloud/conda-forge/noarch
#           package cache : C:\Users\31805\miniconda3\pkgs
#                           C:\Users\31805\.conda\pkgs
#                           C:\Users\31805\AppData\Local\conda\conda\pkgs
#        envs directories : C:\Users\31805\miniconda3\envs
#                           C:\Users\31805\.conda\envs
#                           C:\Users\31805\AppData\Local\conda\conda\envs
#     temporary directory : C:\Users\31805\AppData\Local\Temp
#                platform : win-64
#              user-agent : conda/26.1.1 requests/2.32.5 CPython/3.13.12 Windows/11 Windows/10.0.26200 solver/libmamba conda-libmamba-solver/25.11.0 libmambapy/2.3.2 aau/0.7.5 c/. s/. e/.
#           administrator : False
#              netrc file : None
#            offline mode : False

# %%
import torch
torch.manual_seed(123)
torch.randn(5, 3)
# Out:
# tensor([[-0.1115,  0.1204, -0.3696],
#         [-0.2404, -1.1969,  0.2093],
#         [-0.9724, -0.7550,  0.3239],
#         [-0.1085,  0.2103, -0.3908],
#         [ 0.2350,  0.6653,  0.3528]])

# %%
torch.cuda.is_available()
# Out:
# False
